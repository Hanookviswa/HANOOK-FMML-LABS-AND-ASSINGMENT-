# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanookviswa/HANOOK-FMML-LABS-AND-ASSINGMENT-/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:09:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   171MB/s    in 0.4s
#
# 2023-05-05 04:09:42 (171 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 28503  1706.08801v2  We propose an algorithm to detect approximate ...    cs
# 24752   1411.4734v4  In this paper we address three different compu...    cs
# 13476   0812.0882v1  The stucture determination of a neural network...    cs
# 36907  1509.08086v1  Demand for high software reliability requires ...    cs
# 32328  1502.00064v1  We propose a batchwise monotone algorithm for ...    cs
# ...             ...                                                ...   ...
# 31514  1803.05851v1  In this paper, a framework of video face repla...    cs
# 38846  1604.02488v1  A method for segmenting water bodies in optica...    cs
# 36086   1406.2161v1  The Dynamic Logic for Propositional Assignment...    cs
# 10422   1107.3133v2  We propose a method for nonparametric density ...  stat
# 25147  1506.01497v3  State-of-the-art object detection networks dep...    cs
#
#                                                    title  year  \
# 28503  Approximate Reflection Symmetry in a Point Set...  2017
# 24752  Predicting Depth, Surface Normals and Semantic...  2014
# 13476  Elagage d'un perceptron multicouches : utilisa...  2008
# 36907  Optimal Release Time Decision from Fuzzy Mathe...  2015
# 32328  A Batchwise Monotone Algorithm for Dictionary ...  2015
# ...                                                  ...   ...
# 31514  Image Registration Based Flicker Solving in Vi...  2018
# 38846  Application of Multifractal Analysis to Segmen...  2016
# 36086  Tableaux for Dynamic Logic of Propositional As...  2014
# 10422                   Robust Kernel Density Estimation  2011
# 25147  Faster R-CNN: Towards Real-Time Object Detecti...  2015
#
#                                                 keywords
# 28503  [algorithm, approximate, reflection, volumetri...
# 24752  [different, architecture, prediction, estimati...
# 13476  [determination, modelisation, framework, algor...
# 36907  [reliability, requirement, techniques, predict...
# 32328  [batchwise, algorithm, dictionary, dictionary,...
# ...                                                  ...
# 31514  [framework, replacement, framework, innovation...
# 38846  [segmenting, synthetic, satellite, different, ...
# 36086  [propositional, assignments, alternative, prop...
# 10422  [nonparametric, estimation, robustness, contam...
# 25147  [detection, algorithms, hypothesize, locations...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 28503    [algorithm, approximate, reflection, volumetri...
# 24752    [different, architecture, prediction, estimati...
# 13476    [determination, modelisation, framework, algor...
# 36907    [reliability, requirement, techniques, predict...
# 32328    [batchwise, algorithm, dictionary, dictionary,...
#                                ...
# 36052    [fundamental, development, demanding, evolutio...
# 39653    [monocular, technology, applications, leverage...
# 21941    [algorithm, unsupervised, unlabeled, technique...
# 12874    [recurrent, particular, demonstrated, artifici...
# 37861    [addresses, identifying, dimensional, represen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8803 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c13a44a3-e8a4-4b37-a6be-f5c4829c7bed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c13a44a3-e8a4-4b37-a6be-f5c4829c7bed")) {                    Plotly.newPlot(                        "c13a44a3-e8a4-4b37-a6be-f5c4829c7bed",                        [{"x":["approximate","different","correspondences","independent","comparisons","perturbation","detecting","belonging","demonstrate","reflections","riemannian","distribution","transformation","framework","reflection","optimization","detection","containing","algorithm","establishing","determining","distortion","descriptor","application","robustness","assignment","distributed","distorted","formulate","effectiveness","estimates","multiscale","benchmarks","progressively","architecture","modifications","predictions","predicting","segmentation","estimation","superpixels","regressing","prediction","convolutional","performance","parameters","determination","algorithms","utilisation","performances","literature","simulation","perceptron","sensitivity","techniques","considering","mathematical","assessment","requirement","developed","addresses","adaptability","reliability","programming","perspective","formulated","procedures","dictionary","constraint","converges","objective","switching","experiments","reconstruction","introduce","orthogonal","decreases","furthermore","procedure","accomplish","approximation","coefficient","monotonically","constraints","allocated","cognitive","supervised","phenomenon","analogous","classifying","associations","subsumption","associated","recognizing","independently","phenomena","questions","psychology","attention","requiring","analogies","generation","photovoltaic","assessing","generated","information","challenge","integrating","increased","environmental","electricity","aggregation","selection","regression","inequality","irrelevant","construction","previously","coefficients","functions","simulated","regularization","suboptimal","anisotropic","parameter","situations","adaptation","selectors","particular","especially","effective","tomography","exploiting","capability","challenging","challenges","resolution","modelling","successfully","generalizable","difficulty","relatively","generalization","transfers","transferring","naturally","representational","experiment","insufficient","convolution","maximizing","interpretable","adversarial","probability","indication","statistical","discriminator","individual","criticism","unsupervised","distinguishability","distinguished","reference","estimated","optimized","distributions","representation","classifier","realistic","generative","particularly","discrepancy","significantly","following","universal","mathematically","formalised","essential","reasonable","intelligence","fundamental","definition","definitions","artificial","arbitrary","differences","screening","potentially","necessary","architectures","structures","requirements","replacing","inadequate","consideration","conclusion","highlight","additionally","downsampled","preprocessing"],"y":[100,760,15,123,32,8,64,16,558,6,12,222,50,520,10,311,330,48,790,16,27,18,28,246,108,29,92,6,50,223,84,13,69,12,233,15,92,77,195,240,11,5,219,346,909,237,14,602,2,38,117,74,25,29,384,68,65,53,37,212,49,3,29,137,71,48,38,46,93,29,166,11,603,94,361,18,16,161,117,11,127,23,4,151,5,61,202,26,9,42,9,5,92,44,35,39,82,15,167,46,6,146,1,18,152,701,144,36,38,17,5,25,149,116,8,11,69,96,29,219,50,98,19,6,131,51,63,0,278,114,254,13,73,47,286,124,94,52,86,5,36,65,97,6,16,65,11,75,14,44,26,34,111,141,2,154,16,117,1,136,0,8,62,64,57,98,351,140,66,124,77,18,264,91,45,11,2,64,27,108,86,50,23,140,87,51,9,44,73,113,133,60,13,6,25,11,24,69,2,31],"type":"bar"},{"x":["approximate","different","correspondences","independent", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7816666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Paired</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparisons</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.6226415094339623);'>Interactive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style='background-color:rgba(0, 255, 0, 0.3777777777777778);'>Evolution</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.6226415094339623);'>Interactive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style='background-color:rgba(0, 255, 0, 0.3777777777777778);'>Evolution</span> <span style=''>(IDE)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>paired</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>user</span> <span style=''>fatigue</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>speed</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6226415094339623);'>Interactive</span> <span style=''>Genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>(IGA)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tournament</span> <span style=''>IGA</span> <span style=''>User</span> <span style='background-color:rgba(0, 255, 0, 0.6086956521739132);'>interface</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>are</span> <span style=''>two</span> <span style=''>big</span> <span style=''>keys</span> <span style=''>for</span> <span style=''>reducing</span> <span style='background-color:rgba(0, 255, 0, 0.6226415094339623);'>Interactive</span> <span style='background-color:rgba(0, 255, 0, 0.7941176470588235);'>Evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <span style=''>(IEC)</span> <span style=''>user</span> <span style=''>fatigue</span> <span style=''>Unlike</span> <span style=''>IGA</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conventional</span> <span style=''>IDE</span> <span style=''>users</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>IDE</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tournament</span> <span style=''>IGA</span> <span style=''>do</span> <span style=''>not</span> <span style=''>need</span> <span style=''>to</span> <span style=''>compare</span> <span style=''>whole</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individuals</span> <span style=''>each</span> <span style=''>other</span> <span style=''>but</span> <span style=''>compare</span> <span style=''>pairs</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individuals</span> <span style=''>which</span> <span style=''>largely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreases</span> <span style=''>user</span> <span style=''>fatigue</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style=''>pseudo</span> <span style=''>IEC</span> <span style=''>user</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>another</span> <span style=''>factor</span> <span style=''>IEC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Learn</span> <span style=''>without</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>by</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>We</span> <span style=''>learn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizers</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>by</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizers</span> <span style=''>exhibit</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remarkable</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>transfer</span> <span style=''>in</span> <span style=''>that</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>optimize</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivative</span> <span style=''>free</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>bandits</span> <span style=''>simple</span> <span style=''>control</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <span style=''>and</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <span style=''>tasks</span> <span style=''>Up</span> <span style=''>to</span> <span style=''>the</span> <span style=''>training</span> <span style=''>horizon</span> <span style=''>the</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizers</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>trade</span> <span style=''>off</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>and</span> <span style=''>compare</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favourably</span> <span style=''>with</span> <span style=''>heavily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineered</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>packages</span> <span style=''>for</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Gradient</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.32503888024883365);'>Inference</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Continuous</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Models</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Auxiliary</span> <span style=''>Form</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.32503888024883365);'>inference</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>layers</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>latent</span> <span style=''>vari</span> <span style=''>ables</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>in</span> <span style=''>many</span> <span style=''>cases</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>express</span> <span style=''>such</span> <span style=''>models</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>auxiliary</span> <span style=''>form</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.4222222222222223);'>variables</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615384);'>conditionally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>given</span> <span style=''>their</span> <span style=''>parents</span> <span style=''>and</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>auxiliary</span> <span style='background-color:rgba(255, 0, 0, 0.4222222222222223);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.4222222222222223);'>Variables</span> <span style=''>of</span> <span style=''>mod</span> <span style=''>els</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>auxiliary</span> <span style=''>form</span> <span style=''>have</span> <span style=''>much</span> <span style=''>larger</span> <span style=''>Markov</span> <span style=''>blankets</span> <span style=''>leading</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3216374269005848);'>significant</span> <span style=''>speedups</span> <span style=''>in</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.32503888024883365);'>inference</span> <span style=''>eg</span> <span style=''>rapid</span> <span style=''>mixing</span> <span style=''>Hybrid</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>The</span> <span style=''>relative</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Diet2Vec</span> <span style=''>Multi</span> <span style=''>scale</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>massive</span> <span style=''>dietary</span> <span style=''>data</span> <br/><br/><span style=''>Smart</span> <span style=''>phone</span> <span style=''>apps</span> <span style=''>that</span> <span style=''>enable</span> <span style=''>users</span> <span style=''>to</span> <span style=''>easily</span> <span style=''>track</span> <span style=''>their</span> <span style=''>diets</span> <span style=''>have</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>widespread</span> <span style=''>in</span> <span style=''>the</span> <span style=''>last</span> <span style=''>decade</span> <span style=''>This</span> <span style=''>has</span> <span style=''>created</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>opportunity</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>new</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>obesity</span> <span style=''>and</span> <span style=''>weight</span> <span style=''>loss</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>eating</span> <span style=''>habits</span> <span style=''>of</span> <span style=''>the</span> <span style=''>users</span> <span style=''>of</span> <span style=''>such</span> <span style=''>apps</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>diet2vec</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>modeling</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>a</span> <span style=''>massive</span> <span style=''>database</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>electronic</span> <span style=''>diet</span> <span style=''>journals</span> <span style=''>Through</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>contract</span> <span style=''>and</span> <span style=''>expand</span> <span style=''>process</span> <span style=''>our</span> <span style=''>model</span> <span style=''>learns</span> <span style=''>real</span> <span style=''>valued</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style=''>users</span> <span style=''>diets</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>foods</span> <span style=''>and</span> <span style=''>meals</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>on</span> <span style=''>a</span> <span style=''>real</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>55K</span> <span style=''>users</span> <span style=''>of</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>diet</span> <span style=''>tracking</span> <span style=''>app</span> <span style=''>LoseItfootnotehttpwwwloseitcom</span> <span style=''>To</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.10042735042735043)
# 	architecture (0.08297720797720798)
# 	processing (0.10968660968660969)
# 	segmentation (0.06944444444444445)
# 	challenging (0.10185185185185185)
# 	detection (0.11752136752136752)
# 	information (0.24964387464387464)
# 	convolutional (0.12321937321937322)
# 	different (0.2706552706552707)
# 	recognition (0.1306980056980057)
#
# Some Statistics words are:
# 	estimation (0.17369477911646586)
# 	stochastic (0.13453815261044177)
# 	theoretical (0.1465863453815261)
# 	statistical (0.15512048192771086)
# 	variables (0.14457831325301204)
# 	distribution (0.1892570281124498)
# 	algorithm (0.3950803212851406)
# 	dimensional (0.19176706827309237)
# 	inference (0.21385542168674698)
# 	regression (0.18323293172690763)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="885ac893-ab49-4736-9379-d1c5491438c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("885ac893-ab49-4736-9379-d1c5491438c0")) {                    Plotly.newPlot(                        "885ac893-ab49-4736-9379-d1c5491438c0",                        [{"x":["approximate","different","correspondences","independent","comparisons","perturbation","detecting","belonging","demonstrate","reflections","riemannian","distribution","transformation","framework","reflection","optimization","detection","containing","algorithm","establishing","determining","distortion","descriptor","application","robustness","assignment","distributed","distorted","formulate","effectiveness","estimates","multiscale","benchmarks","progressively","architecture","modifications","predictions","predicting","segmentation","estimation","superpixels","regressing","prediction","convolutional","performance","parameters","determination","algorithms","utilisation","performances","literature","simulation","perceptron","sensitivity","techniques","considering","mathematical","assessment","requirement","developed","addresses","adaptability","reliability","programming","perspective","formulated","procedures","dictionary","constraint","converges","objective","switching","experiments","reconstruction","introduce","orthogonal","decreases","furthermore","procedure","accomplish","approximation","coefficient","monotonically","constraints","allocated","cognitive","supervised","phenomenon","analogous","classifying","associations","subsumption","associated","recognizing","independently","phenomena","questions","psychology","attention","requiring","analogies","generation","photovoltaic","assessing","generated","information","challenge","integrating","increased","environmental","electricity","aggregation","selection","regression","inequality","irrelevant","construction","previously","coefficients","functions","simulated","regularization","suboptimal","anisotropic","parameter","situations","adaptation","selectors","particular","especially","effective","tomography","exploiting","capability","challenging","challenges","resolution","modelling","successfully","generalizable","difficulty","relatively","generalization","transfers","transferring","naturally","representational","experiment","insufficient","convolution","maximizing","interpretable","adversarial","probability","indication","statistical","discriminator","individual","criticism","unsupervised","distinguishability","distinguished","reference","estimated","optimized","distributions","representation","classifier","realistic","generative","particularly","discrepancy","significantly","following","universal","mathematically","formalised","essential","reasonable","intelligence","fundamental","definition","definitions","artificial","arbitrary","differences","screening","potentially","necessary","architectures","structures","requirements","replacing","inadequate","consideration","conclusion","highlight","additionally","downsampled","preprocessing","specifically","increases","difference","investigating","evaluating","capturing","improvements","summarization","extremely","synonymous","summaries","automatic","limitations","evaluation","segmentations","inference","probabilistic","homogeneous","comparable","advantage","corresponding","quantitative","partitioning","generalizes","annotations","consistent","recursively","formalized","applicability","corrected","adjacency","embedding","clustering","stochastic","blockmodel","extensive","excellent","efficient","quantification","background","community","important","elliptical","initially","performed","specialists","splitting","described","processing","annotation","similarity","preserving","relations","extracting" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	selectors
# 	distinguishability
# 	blockmodel
# 	privileged
# 	criterions
# 	robustify
# 	correntropy
# 	homoscedastic
# 	elucidate
# 	syndromes
# 	subpopulations
# 	emphsparse
# 	clairvoyant
# 	ferromagnetic
# 	recoverability
# 	robustifying
# 	recidivism
# 	periodicity
# 	statistician
# 	beginnings
# Some words which never appear in Statistics papers:
# 	reflections
# 	reflection
# 	utilisation
# 	allocated
# 	subsumption
# 	formalised
# 	downsampled
# 	synonymous
# 	centrally
# 	hazardous
# 	contrasted
# 	avoidance
# 	fatalities
# 	warehouse
# 	proficiency
# 	crowdworkers
# 	questionnaire
# 	uncalibrated
# 	complementarity
# 	internship

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061380682687892e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7416666666666667
